# %% [markdown]
# <a href="https://colab.research.google.com/github/10172828/BIG-DATA/blob/main/ASS3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv")
#print(data)
plt.plot(data['total_profit'],data['month_number'])
plt.title("line plot")
plt.xlabel('day')
plt.ylabel('tip')
plt.show()
